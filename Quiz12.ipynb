# %% [markdown]
# <a href="https://colab.research.google.com/github/ronish645/CS455_RONISH_19707/blob/main/Quiz12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Q1
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class SinglyLinkedList:
    def __init__(self):
        self.head = None

    def create(self, data_list):
        for data in data_list:
            self.insert_at_end(data)

    def insert_at_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_node

    def insert_at_beginning(self, data):
        new_node = Node(data)
        new_node.next = self.head
        self.head = new_node

    def insert_after(self, prev_data, data):
        current = self.head
        while current and current.data != prev_data:
            current = current.next
        if current is None:
            print(f"Node with data {prev_data} not found.")
        else:
            new_node = Node(data)
            new_node.next = current.next
            current.next = new_node

    def delete_node(self, key):
        current = self.head
        if current and current.data == key:
            self.head = current.next
            current = None
            return

        prev = None
        while current and current.data != key:
            prev = current
            current = current.next

        if current is None:
            print(f"Node with data {key} not found.")
            return

        prev.next = current.next
        current = None

    def traverse(self):
        current = self.head
        while current:
            print(current.data, end=" -> ")
            current = current.next
        print("None")

# Example usage
if __name__ == "__main__":
    sll = SinglyLinkedList()

    # Creation
    sll.create([1, 2, 3, 4])
    print("Linked List after creation:")
    sll.traverse()

    # Insertion at end
    sll.insert_at_end(5)
    print("Linked List after insertion at end:")
    sll.traverse()

    # Insertion at beginning
    sll.insert_at_beginning(0)
    print("Linked List after insertion at beginning:")
    sll.traverse()

    # Insertion after a node
    sll.insert_after(3, 3.5)
    print("Linked List after insertion after node with data 3:")
    sll.traverse()

    # Deletion of a node
    sll.delete_node(3.5)
    print("Linked List after deletion of node with data 3.5:")
    sll.traverse()
# Out:
# Linked List after creation:
# 1 -> 2 -> 3 -> 4 -> None
# Linked List after insertion at end:
# 1 -> 2 -> 3 -> 4 -> 5 -> None
# Linked List after insertion at beginning:
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> None
# Linked List after insertion after node with data 3:
# 0 -> 1 -> 2 -> 3 -> 3.5 -> 4 -> 5 -> None
# Linked List after deletion of node with data 3.5:
# 0 -> 1 -> 2 -> 3 -> 4 -> 5 -> None

# %%
#Q2
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None
        self.prev = None

class DoublyLinkedList:
    def __init__(self):
        self.head = None

    def create(self, data_list):
        for data in data_list:
            self.insert_end(data)

    def insert_end(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        last = self.head
        while last.next:
            last = last.next
        last.next = new_node
        new_node.prev = last

    def insert_beginning(self, data):
        new_node = Node(data)
        if not self.head:
            self.head = new_node
            return
        self.head.prev = new_node
        new_node.next = self.head
        self.head = new_node

    def insert_after(self, prev_node, data):
        if not prev_node:
            print("The given previous node must be in the LinkedList.")
            return
        new_node = Node(data)
        new_node.next = prev_node.next
        new_node.prev = prev_node
        if prev_node.next:
            prev_node.next.prev = new_node
        prev_node.next = new_node

    def delete_node(self, key):
        temp = self.head

        while temp:
            if temp.data == key:
                break
            temp = temp.next

        if temp is None:
            print("Node with data", key, "not found.")
            return

        if temp.prev:
            temp.prev.next = temp.next
        if temp.next:
            temp.next.prev = temp.prev
        if temp == self.head:
            self.head = temp.next

        temp = None

    def traverse_forward(self):
        current = self.head
        while current:
            print(current.data, end=" <-> ")
            current = current.next
        print("None")

    def traverse_backward(self):
        current = self.head
        if not current:
            print("The list is empty.")
            return
        while current.next:
            current = current.next
        while current:
            print(current.data, end=" <-> ")
            current = current.prev
        print("None")

# Example usage:
dll = DoublyLinkedList()
dll.create([1, 2, 3, 4, 5])
print("Doubly Linked List after creation (forward traversal):")
dll.traverse_forward()

dll.insert_end(6)
print("Doubly Linked List after insertion at end (forward traversal):")
dll.traverse_forward()

dll.insert_beginning(0)
print("Doubly Linked List after insertion at beginning (forward traversal):")
dll.traverse_forward()

dll.insert_after(dll.head.next, 1.5)
print("Doubly Linked List after insertion after node with data 1 (forward traversal):")
dll.traverse_forward()

dll.delete_node(3)
print("Doubly Linked List after deletion of node with data 3 (forward traversal):")
dll.traverse_forward()

print("Doubly Linked List after deletion of node with data 3 (backward traversal):")
dll.traverse_backward()
# Out:
# Doubly Linked List after creation (forward traversal):
# 1 <-> 2 <-> 3 <-> 4 <-> 5 <-> None
# Doubly Linked List after insertion at end (forward traversal):
# 1 <-> 2 <-> 3 <-> 4 <-> 5 <-> 6 <-> None
# Doubly Linked List after insertion at beginning (forward traversal):
# 0 <-> 1 <-> 2 <-> 3 <-> 4 <-> 5 <-> 6 <-> None
# Doubly Linked List after insertion after node with data 1 (forward traversal):
# 0 <-> 1 <-> 1.5 <-> 2 <-> 3 <-> 4 <-> 5 <-> 6 <-> None
# Doubly Linked List after deletion of node with data 3 (forward traversal):
# 0 <-> 1 <-> 1.5 <-> 2 <-> 4 <-> 5 <-> 6 <-> None
# Doubly Linked List after deletion of node with data 3 (backward traversal):
# 6 <-> 5 <-> 4 <-> 2 <-> 1.5 <-> 1 <-> 0 <-> None

# %%
#Queue using arrays
class QueueArray:
    def __init__(self, capacity):
        self.capacity = capacity
        self.queue = [None] * capacity
        self.front = self.size = 0
        self.rear = capacity - 1

    def is_full(self):
        return self.size == self.capacity

    def is_empty(self):
        return self.size == 0

    def enqueue(self, item):
        if self.is_full():
            print("Queue is full!")
            return
        self.rear = (self.rear + 1) % self.capacity
        self.queue[self.rear] = item
        self.size += 1
        print(f"Enqueued {item}")

    def dequeue(self):
        if self.is_empty():
            print("Queue is empty!")
            return
        item = self.queue[self.front]
        self.front = (self.front + 1) % self.capacity
        self.size -= 1
        print(f"Dequeued {item}")
        return item

    def front_item(self):
        if self.is_empty():
            print("Queue is empty!")
            return None
        return self.queue[self.front]

    def rear_item(self):
        if self.is_empty():
            print("Queue is empty!")
            return None
        return self.queue[self.rear]

# Example usage:
queue_array = QueueArray(5)
queue_array.enqueue(1)
queue_array.enqueue(2)
queue_array.enqueue(3)
queue_array.enqueue(4)
queue_array.enqueue(5)

print("Queue after enqueuing 5 elements:")
print("Front item is:", queue_array.front_item())
print("Rear item is:", queue_array.rear_item())

queue_array.dequeue()
queue_array.enqueue(6)

print("Queue after dequeueing 1 element and enqueuing 6:")
print("Front item is:", queue_array.front_item())
print("Rear item is:", queue_array.rear_item())
# Out:
# Enqueued 1
# Enqueued 2
# Enqueued 3
# Enqueued 4
# Enqueued 5
# Queue after enqueuing 5 elements:
# Front item is: 1
# Rear item is: 5
# Dequeued 1
# Enqueued 6
# Queue after dequeueing 1 element and enqueuing 6:
# Front item is: 2
# Rear item is: 6

# %%
#Queue using linked list
class Node:
    def __init__(self, data):
        self.data = data
        self.next = None

class QueueLinkedList:
    def __init__(self):
        self.front = self.rear = None

    def is_empty(self):
        return self.front is None

    def enqueue(self, item):
        new_node = Node(item)
        if self.rear is None:
            self.front = self.rear = new_node
            print(f"Enqueued {item}")
            return
        self.rear.next = new_node
        self.rear = new_node
        print(f"Enqueued {item}")

    def dequeue(self):
        if self.is_empty():
            print("Queue is empty!")
            return
        temp = self.front
        self.front = temp.next
        if self.front is None:
            self.rear = None
        print(f"Dequeued {temp.data}")
        return temp.data

    def front_item(self):
        if self.is_empty():
            print("Queue is empty!")
            return None
        return self.front.data

    def rear_item(self):
        if self.is_empty():
            print("Queue is empty!")
            return None
        return self.rear.data

# Example usage:
queue_linked_list = QueueLinkedList()
queue_linked_list.enqueue(1)
queue_linked_list.enqueue(2)
queue_linked_list.enqueue(3)
queue_linked_list.enqueue(4)
queue_linked_list.enqueue(5)

print("Queue after enqueuing 5 elements:")
print("Front item is:", queue_linked_list.front_item())
print("Rear item is:", queue_linked_list.rear_item())

queue_linked_list.dequeue()
queue_linked_list.enqueue(6)

print("Queue after dequeueing 1 element and enqueuing 6:")
print("Front item is:", queue_linked_list.front_item())
print("Rear item is:", queue_linked_list.rear_item())
# Out:
# Enqueued 1
# Enqueued 2
# Enqueued 3
# Enqueued 4
# Enqueued 5
# Queue after enqueuing 5 elements:
# Front item is: 1
# Rear item is: 5
# Dequeued 1
# Enqueued 6
# Queue after dequeueing 1 element and enqueuing 6:
# Front item is: 2
# Rear item is: 6
